# %%
# write import statements
import time
import pandas as pd
import datetime
import os
import random
import seaborn as sns

# %%
# declare file path that contains text files
filePath=r"C:\Users\immanuel\Desktop\FEED MIGRATION\Data Migration\Sales Data"

# %%
# change directory
os.chdir(filePath)

# %%
# list files in directory
os.listdir()
# Out:
# ['AL-Sales Data.txt',
#  'AZ-Sales Data.txt',
#  'CA-Sales Data.txt',
#  'CO-Sales Data.txt',
#  'CT-Sales Data.txt',
#  'DC-Sales Data.txt',
#  'ID-Sales Data.txt',
#  'IL-Sales Data.txt',
#  'IN-Sales Data.txt',
#  'LA-Sales Data.txt',
#  'MA-Sales Data.txt',
#  'ME-Sales Data.txt',
#  'MI-Sales Data.txt',
#  'MN-Sales Data.txt',
#  'MO-Sales Data.txt',
#  'MS-Sales Data.txt',
#  'NE-Sales Data.txt',
#  'NJ-Sales Data.txt',
#  'NM-Sales Data.txt',
#  'NV-Sales Data.txt',
#  'NY-Sales Data.txt',
#  'OH-Sales Data.txt',
#  'OK-Sales Data.txt',
#  'OR-Sales Data.txt',
#  'RI-Sales Data.txt',
#  'SC-Sales Data.txt',
#  'Summary',
#  'TX-Sales Data.txt',
#  'UT-Sales Data.txt',
#  'WA-Sales Data.txt']

# %%
# cannot write a line per text file
pd.read_csv('AL-Sales Data.txt')
# Out:
#     State        City     Investment        Revenue        Date Property Type
# 0      AL  MONTGOMERY    $792,535.94    $624,230.00  2011-01-03   Commercial
# 1      AL  MONTGOMERY  $1,285,051.00  $1,802,400.00  2011-01-05   Commercial
# 2      AL  MONTGOMERY  $2,449,821.30  $1,989,170.00  2011-01-08   Commercial
# 3      AL  MONTGOMERY    $325,140.64    $482,820.00  2011-01-10          Land
# 4      AL  MONTGOMERY    $382,512.57    $523,875.00  2011-01-26          Land
# ..    ...         ...            ...            ...         ...           ...
# 608    AL  MONTGOMERY    $506,946.08    $407,490.00  2020-10-27          Land
# 609    AL  MONTGOMERY    $144,732.99    $127,590.00  2020-11-08    Industrial
# 610    AL  MONTGOMERY    $805,687.52    $920,670.00  2020-11-15    Industrial
# 611    AL  MONTGOMERY  $1,335,939.06  $1,102,815.00  2020-11-18    Industrial
# 612    AL  MONTGOMERY    $423,568.30    $428,725.00  2020-11-26   Residential
#
# [613 rows x 6 columns]

# %%
# read in text files with a loop
l1=[]
for x in os.listdir():
    ext=os.path.splitext(x)[1]
    if ext == ".txt":
        l1.append(pd.read_csv(x))
pd.concat(l1)

# %%
# use list comprehension to read in all text files
df=pd.concat([pd.read_csv(x) for x in os.listdir() if os.path.splitext(x)[1]==".txt"])

# %%
# display dataframe
df
# Out:
#      State        City     Investment        Revenue        Date Property Type
# 0       AL  MONTGOMERY    $792,535.94    $624,230.00  2011-01-03   Commercial
# 1       AL  MONTGOMERY  $1,285,051.00  $1,802,400.00  2011-01-05   Commercial
# 2       AL  MONTGOMERY  $2,449,821.30  $1,989,170.00  2011-01-08   Commercial
# 3       AL  MONTGOMERY    $325,140.64    $482,820.00  2011-01-10          Land
# 4       AL  MONTGOMERY    $382,512.57    $523,875.00  2011-01-26          Land
# ...    ...         ...            ...            ...         ...           ...
# 1653    WA     OLYMPIA    $732,022.00  $1,008,795.00  2020-11-11    Industrial
# 1654    WA     SPOKANE    $734,743.08    $560,355.00  2020-11-14    Industrial
# 1655    WA     SPOKANE  $1,134,116.70  $1,266,660.00  2020-11-15    Industrial
# 1656    WA      TACOMA  $1,404,903.79  $1,000,650.00  2020-11-27   Commercial
# 1657    WA  BELLINGHAM    $342,616.18    $517,025.00  2020-11-30   Residential
#
# [26993 rows x 6 columns]

# %%
# declare filepath for references
RefFilePath=r"C:\Users\immanuel\Desktop\FEED MIGRATION\Data Migration\City-Region Ref.xlsx"

# %%
# you need to read in all tabs
# this line only reads in the first tab
pd.read_excel(filePath)
# Out:
#                  Region                     City
# 0               Midwest              Chicago, IL
# 1               Midwest             Rockford, IL
# 2               Midwest             Columbus, OH
# 3               Midwest            Cleveland, OH
# 4               Midwest           Cincinnati, OH
# 5               Midwest              Detroit, MI
# 6               Midwest              Lansing, MI
# 7               Midwest                Omaha, NE
# 8               Midwest            St. Louis, MO
# 9               Midwest           Fort Wayne, IN
# 10              Midwest          Minneapolis, MN
# 11            Northeast               Boston, MA
# 12            Northeast             New York, NY
# 13            Northeast               Albany, NY
# 14            Northeast            Rochester, NY
# 15            Northeast  Fairfield-New Haven, CT
# 16            Northeast              Trenton, NJ
# 17            Northeast               Newark, NJ
# 18            Northeast          Jersey City, NJ
# 19            Northeast           Providence, RI
# 20            Northeast           Washington, DC
# 21            Northeast             Portland, ME
# 22  Northern California             San Jose, CA
# 23  Northern California        San Francisco, CA
# 24  Northern California     Oakland-East Bay, CA
# 25    Pacific Northwest              Seattle, WA
# 26    Pacific Northwest           Bellingham, WA
# 27    Pacific Northwest              Olympia, WA
# 28    Pacific Northwest              Spokane, WA
# 29    Pacific Northwest                 Bend, OR
# 30    Pacific Northwest             Portland, OR
# 31    Pacific Northwest                Boise, ID
# 32    Pacific Northwest               Tacoma, WA
# 33    Pacific Northwest          Idaho Falls, ID
# 34                South               Dallas, TX
# 35                South              Houston, TX
# 36                South        Oklahoma City, OK
# 37                South                Tulsa, OK
# 38                South           Montgomery, AL
# 39                South             Columbia, SC
# 40                South          Baton Rouge, LA
# 41                South              Jackson, MS
# 42         Southwestern              Pheonix, AZ
# 43         Southwestern             Santa Fe, NM
# 44         Southwestern               Denver, CO
# 45         Southwestern            Las Vegas, NV
# 46         Southwestern       Salt Lake City, UT
# 47  Southern California        Orange County, CA
# 48  Southern California            San Diego, CA
# 49  Southern California          Los Angeles, CA

# %%
# https://stackoverflow.com/questions/26521266/using-pandas-to-pd-read-excel-for-multiple-worksheets-of-the-same-workbook
# read in all tabs
# this returns an ordered dict
REF=pd.read_excel(filePath, sheet_name=None)
refList==[REF[x] for x in REF]
# print each tab
# refList[0]
# refList[1]
# refList[2]

# %%
# unpack tabs into dataframes
City,Manager,Rep=[REF[x] for x in REF]

# %%
# print each tab
# City
# Manager
# Rep

# %%
# merge df with Ref tables
def combine(df):
    state=df["State"]
    city=df["City"]
    return f"{city}, {state}"
df["City, State"]=df.apply(combine, axis=1)
# https://stackoverflow.com/questions/39512002/convert-whole-dataframe-from-lower-case-to-upper-case-with-pandas
City=City.apply(lambda x: x.astype(str).str.upper())
Manager=Manager.apply(lambda x: x.astype(str).str.upper())
Rep=Rep.apply(lambda x: x.astype(str).str.upper())

# %%
# this returns duplicate columns
df.merge(City, left_on='City, State', right_on='City')
# Out:
#           City, State   Region_x State      City_x  Investment    Revenue  \
# 0          ALBANY, NY  NORTHEAST    NY      ALBANY   118319.21   203880.0
# 1          ALBANY, NY  NORTHEAST    NY      ALBANY   287296.62   281760.0
# 2          ALBANY, NY  NORTHEAST    NY      ALBANY   588534.07   668287.5
# 3          ALBANY, NY  NORTHEAST    NY      ALBANY  1630159.26  1728700.0
# 4          ALBANY, NY  NORTHEAST    NY      ALBANY   758424.58   681935.0
# ...               ...        ...   ...         ...         ...        ...
# 26988  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   344056.49   329295.0
# 26989  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   188671.89   247215.0
# 26990  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   631405.48   833740.0
# 26991  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1591752.00  1698030.0
# 26992  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1979480.67  1678940.0
#
#             Date Property Type Regional Manager        City Rep  Net Income  \
# 0     2011-01-06   Residential    MARCELA MAXIM      JYRI SINGH    85560.79
# 1     2011-01-09   Residential    MARCELA MAXIM      JYRI SINGH    -5536.62
# 2     2011-01-13          Land    MARCELA MAXIM      JYRI SINGH    79753.43
# 3     2011-01-13   Commercial     MARCELA MAXIM      JYRI SINGH    98540.74
# 4     2011-01-15   Residential    MARCELA MAXIM      JYRI SINGH   -76489.58
# ...          ...           ...              ...             ...         ...
# 26988 2020-11-18   Residential    MARCELA MAXIM  ASHWIN COGHLAN   -14761.49
# 26989 2020-11-19   Residential    MARCELA MAXIM  ASHWIN COGHLAN    58543.11
# 26990 2020-11-20   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   202334.52
# 26991 2020-11-27   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   106278.00
# 26992 2020-11-29   Commercial     MARCELA MAXIM  ASHWIN COGHLAN  -300540.67
#
#       Profit/Loss   ROI  year  month quarter   Region_y          City_y
# 0          Profit  0.72  2011      1     Q 1  NORTHEAST      ALBANY, NY
# 1            Loss -0.02  2011      1     Q 1  NORTHEAST      ALBANY, NY
# 2          Profit  0.14  2011      1     Q 1  NORTHEAST      ALBANY, NY
# 3          Profit  0.06  2011      1     Q 1  NORTHEAST      ALBANY, NY
# 4            Loss -0.10  2011      1     Q 1  NORTHEAST      ALBANY, NY
# ...           ...   ...   ...    ...     ...        ...             ...
# 26988        Loss -0.04  2020     11     Q 4  NORTHEAST  WASHINGTON, DC
# 26989      Profit  0.31  2020     11     Q 4  NORTHEAST  WASHINGTON, DC
# 26990      Profit  0.32  2020     11     Q 4  NORTHEAST  WASHINGTON, DC
# 26991      Profit  0.07  2020     11     Q 4  NORTHEAST  WASHINGTON, DC
# 26992        Loss -0.15  2020     11     Q 4  NORTHEAST  WASHINGTON, DC
#
# [26993 rows x 18 columns]

# %%
# use index instead
# https://stackoverflow.com/questions/36538780/merging-dataframes-on-index-with-pandas
df.set_index("City, State").merge(City.set_index("City"), how='outer', left_index=True, right_index=True)
# Out:
#                State        City     Investment        Revenue        Date  \
# ALBANY, NY        NY      ALBANY    $118,319.21    $203,880.00  2011-01-06
# ALBANY, NY        NY      ALBANY    $287,296.62    $281,760.00  2011-01-09
# ALBANY, NY        NY      ALBANY    $588,534.07    $668,287.50  2011-01-13
# ALBANY, NY        NY      ALBANY  $1,630,159.26  $1,728,700.00  2011-01-13
# ALBANY, NY        NY      ALBANY    $758,424.58    $681,935.00  2011-01-15
# ...              ...         ...            ...            ...         ...
# WASHINGTON, DC    DC  WASHINGTON    $344,056.49    $329,295.00  2020-11-18
# WASHINGTON, DC    DC  WASHINGTON    $188,671.89    $247,215.00  2020-11-19
# WASHINGTON, DC    DC  WASHINGTON    $631,405.48    $833,740.00  2020-11-20
# WASHINGTON, DC    DC  WASHINGTON  $1,591,752.00  $1,698,030.00  2020-11-27
# WASHINGTON, DC    DC  WASHINGTON  $1,979,480.67  $1,678,940.00  2020-11-29
#
#                Property Type     Region
# ALBANY, NY       Residential  NORTHEAST
# ALBANY, NY       Residential  NORTHEAST
# ALBANY, NY              Land  NORTHEAST
# ALBANY, NY       Commercial   NORTHEAST
# ALBANY, NY       Residential  NORTHEAST
# ...                      ...        ...
# WASHINGTON, DC   Residential  NORTHEAST
# WASHINGTON, DC   Residential  NORTHEAST
# WASHINGTON, DC   Commercial   NORTHEAST
# WASHINGTON, DC   Commercial   NORTHEAST
# WASHINGTON, DC   Commercial   NORTHEAST
#
# [26993 rows x 7 columns]

# %%
define funtion to merge index
def MergeIndex(df1,df2,index1,index2):
    df1=df1.set_index(index1)
    df2=df2.set_index(index2)
    mergedDF=df1.merge(df2, how='outer', left_index=True, right_index=True)
    return mergedDF.reset_index().rename(columns={"index": index1})

df=MergeIndex(df,City,"City, State","City")
df=MergeIndex(df,Manager,"Region","Region")
df=MergeIndex(df,Rep,"City, State","City")

# %%
df
# Out:
#           City, State     Region State        City     Investment  \
# 0          ALBANY, NY  NORTHEAST    NY      ALBANY    $118,319.21
# 1          ALBANY, NY  NORTHEAST    NY      ALBANY    $287,296.62
# 2          ALBANY, NY  NORTHEAST    NY      ALBANY    $588,534.07
# 3          ALBANY, NY  NORTHEAST    NY      ALBANY  $1,630,159.26
# 4          ALBANY, NY  NORTHEAST    NY      ALBANY    $758,424.58
# ...               ...        ...   ...         ...            ...
# 26988  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON    $344,056.49
# 26989  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON    $188,671.89
# 26990  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON    $631,405.48
# 26991  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  $1,591,752.00
# 26992  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  $1,979,480.67
#
#              Revenue        Date Property Type Regional Manager  \
# 0        $203,880.00  2011-01-06   Residential    MARCELA MAXIM
# 1        $281,760.00  2011-01-09   Residential    MARCELA MAXIM
# 2        $668,287.50  2011-01-13          Land    MARCELA MAXIM
# 3      $1,728,700.00  2011-01-13   Commercial     MARCELA MAXIM
# 4        $681,935.00  2011-01-15   Residential    MARCELA MAXIM
# ...              ...         ...           ...              ...
# 26988    $329,295.00  2020-11-18   Residential    MARCELA MAXIM
# 26989    $247,215.00  2020-11-19   Residential    MARCELA MAXIM
# 26990    $833,740.00  2020-11-20   Commercial     MARCELA MAXIM
# 26991  $1,698,030.00  2020-11-27   Commercial     MARCELA MAXIM
# 26992  $1,678,940.00  2020-11-29   Commercial     MARCELA MAXIM
#
#              City Rep
# 0          JYRI SINGH
# 1          JYRI SINGH
# 2          JYRI SINGH
# 3          JYRI SINGH
# 4          JYRI SINGH
# ...               ...
# 26988  ASHWIN COGHLAN
# 26989  ASHWIN COGHLAN
# 26990  ASHWIN COGHLAN
# 26991  ASHWIN COGHLAN
# 26992  ASHWIN COGHLAN
#
# [26993 rows x 10 columns]

# %%
# convert string to floats
# series are of object type instead of numbers
df["Investment"]
# Out:
# 0          $118,319.21
# 1          $287,296.62
# 2          $588,534.07
# 3        $1,630,159.26
# 4          $758,424.58
#              ...
# 26988      $344,056.49
# 26989      $188,671.89
# 26990      $631,405.48
# 26991    $1,591,752.00
# 26992    $1,979,480.67
# Name: Investment, Length: 26993, dtype: object

# %%
def convertToFloat(currency):
    for ch in ['$',',']:
        if ch in currency:
            currency = currency.replace(ch,"")
    return float(currency)

# %%
df["Investment"]=df["Investment"].apply(convertToFloat)
df["Revenue"]=df["Revenue"].apply(convertToFloat)

# %%
df.head()
# Out:
#   City, State     Region State    City  Investment    Revenue        Date  \
# 0  ALBANY, NY  NORTHEAST    NY  ALBANY   118319.21   203880.0  2011-01-06
# 1  ALBANY, NY  NORTHEAST    NY  ALBANY   287296.62   281760.0  2011-01-09
# 2  ALBANY, NY  NORTHEAST    NY  ALBANY   588534.07   668287.5  2011-01-13
# 3  ALBANY, NY  NORTHEAST    NY  ALBANY  1630159.26  1728700.0  2011-01-13
# 4  ALBANY, NY  NORTHEAST    NY  ALBANY   758424.58   681935.0  2011-01-15
#
#   Property Type Regional Manager    City Rep
# 0   Residential    MARCELA MAXIM  JYRI SINGH
# 1   Residential    MARCELA MAXIM  JYRI SINGH
# 2          Land    MARCELA MAXIM  JYRI SINGH
# 3   Commercial     MARCELA MAXIM  JYRI SINGH
# 4   Residential    MARCELA MAXIM  JYRI SINGH

# %%
# convert date from string to datetime object
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["Date"]
# Out:
# 0       2011-01-06
# 1       2011-01-09
# 2       2011-01-13
# 3       2011-01-13
# 4       2011-01-15
#            ...
# 26988   2020-11-18
# 26989   2020-11-19
# 26990   2020-11-20
# 26991   2020-11-27
# 26992   2020-11-29
# Name: Date, Length: 26993, dtype: datetime64[ns]

# %%
df["Date"].iloc[0]
# Out:
# Timestamp('2011-01-06 00:00:00')

# %%
# get net income
df["Net Income"]=df["Revenue"]-df["Investment"]

# %%
df
# Out:
#           City, State     Region State        City  Investment    Revenue  \
# 0          ALBANY, NY  NORTHEAST    NY      ALBANY   118319.21   203880.0
# 1          ALBANY, NY  NORTHEAST    NY      ALBANY   287296.62   281760.0
# 2          ALBANY, NY  NORTHEAST    NY      ALBANY   588534.07   668287.5
# 3          ALBANY, NY  NORTHEAST    NY      ALBANY  1630159.26  1728700.0
# 4          ALBANY, NY  NORTHEAST    NY      ALBANY   758424.58   681935.0
# ...               ...        ...   ...         ...         ...        ...
# 26988  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   344056.49   329295.0
# 26989  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   188671.89   247215.0
# 26990  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   631405.48   833740.0
# 26991  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1591752.00  1698030.0
# 26992  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1979480.67  1678940.0
#
#             Date Property Type Regional Manager        City Rep  Net Income
# 0     2011-01-06   Residential    MARCELA MAXIM      JYRI SINGH    85560.79
# 1     2011-01-09   Residential    MARCELA MAXIM      JYRI SINGH    -5536.62
# 2     2011-01-13          Land    MARCELA MAXIM      JYRI SINGH    79753.43
# 3     2011-01-13   Commercial     MARCELA MAXIM      JYRI SINGH    98540.74
# 4     2011-01-15   Residential    MARCELA MAXIM      JYRI SINGH   -76489.58
# ...          ...           ...              ...             ...         ...
# 26988 2020-11-18   Residential    MARCELA MAXIM  ASHWIN COGHLAN   -14761.49
# 26989 2020-11-19   Residential    MARCELA MAXIM  ASHWIN COGHLAN    58543.11
# 26990 2020-11-20   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   202334.52
# 26991 2020-11-27   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   106278.00
# 26992 2020-11-29   Commercial     MARCELA MAXIM  ASHWIN COGHLAN  -300540.67
#
# [26993 rows x 11 columns]

# %%
# determine if there was a profit or loss
df["Profit/Loss"]=df["Net Income"].apply(lambda x:"Profit" if x>0 else "Loss")

# %%
# determine retrn on interest
def ROI(df):
    a=df["Investment"]
    b=df["Net Income"]
    return round((b/a),3)

df["ROI"]=df.apply(ROI, axis=1)

# %%
df
# Out:
#           City, State     Region State        City  Investment    Revenue  \
# 0          ALBANY, NY  NORTHEAST    NY      ALBANY   118319.21   203880.0
# 1          ALBANY, NY  NORTHEAST    NY      ALBANY   287296.62   281760.0
# 2          ALBANY, NY  NORTHEAST    NY      ALBANY   588534.07   668287.5
# 3          ALBANY, NY  NORTHEAST    NY      ALBANY  1630159.26  1728700.0
# 4          ALBANY, NY  NORTHEAST    NY      ALBANY   758424.58   681935.0
# ...               ...        ...   ...         ...         ...        ...
# 26988  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   344056.49   329295.0
# 26989  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   188671.89   247215.0
# 26990  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON   631405.48   833740.0
# 26991  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1591752.00  1698030.0
# 26992  WASHINGTON, DC  NORTHEAST    DC  WASHINGTON  1979480.67  1678940.0
#
#             Date Property Type Regional Manager        City Rep  Net Income  \
# 0     2011-01-06   Residential    MARCELA MAXIM      JYRI SINGH    85560.79
# 1     2011-01-09   Residential    MARCELA MAXIM      JYRI SINGH    -5536.62
# 2     2011-01-13          Land    MARCELA MAXIM      JYRI SINGH    79753.43
# 3     2011-01-13   Commercial     MARCELA MAXIM      JYRI SINGH    98540.74
# 4     2011-01-15   Residential    MARCELA MAXIM      JYRI SINGH   -76489.58
# ...          ...           ...              ...             ...         ...
# 26988 2020-11-18   Residential    MARCELA MAXIM  ASHWIN COGHLAN   -14761.49
# 26989 2020-11-19   Residential    MARCELA MAXIM  ASHWIN COGHLAN    58543.11
# 26990 2020-11-20   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   202334.52
# 26991 2020-11-27   Commercial     MARCELA MAXIM  ASHWIN COGHLAN   106278.00
# 26992 2020-11-29   Commercial     MARCELA MAXIM  ASHWIN COGHLAN  -300540.67
#
#       Profit/Loss   ROI
# 0          Profit  0.72
# 1            Loss -0.02
# 2          Profit  0.14
# 3          Profit  0.06
# 4            Loss -0.10
# ...           ...   ...
# 26988        Loss -0.04
# 26989      Profit  0.31
# 26990      Profit  0.32
# 26991      Profit  0.07
# 26992        Loss -0.15
#
# [26993 rows x 13 columns]

# %%
# get month year and quarter
df["year"]=df["Date"].apply(lambda x:x.year)
df["month"]=df["Date"].apply(lambda x:x.month)
df["quarter"]=df["Date"].apply(lambda x:f"Q {x.quarter}")

# %%
# create heat map:
#     year and month
#     year and region
#     year and city
# groupby objects:
#     year quarter month profit/loss

df.groupby(["year","quarter","month","Region"])["ROI"].mean().to_frame()
# Out:
#                                              ROI
# year quarter month Region
# 2011 Q 1     1     MIDWEST              0.091667
#                    NORTHEAST            0.053788
#                    NORTHERN CALIFORNIA -0.116250
#                    PACIFIC NORTHWEST    0.095714
#                    SOUTH                0.070526
# ...                                          ...
# 2020 Q 4     11    NORTHERN CALIFORNIA -0.111429
#                    PACIFIC NORTHWEST    0.131579
#                    SOUTH                0.063529
#                    SOUTHERN CALIFORNIA -0.057273
#                    SOUTHWESTERN         0.106190
#
# [833 rows x 1 columns]

# %%
def getHeatMap(df,indexList,columnList, axis):
    HeatMap=pd.pivot_table(df, values = 'ROI', index=indexList, columns=columnList)
    HeatMap=HeatMap.round(3).style.background_gradient(cmap=sns.light_palette("blue", as_cmap=True),axis=axis)
    return HeatMap

# %%
getHeatMap(df,
           indexList=["year","quarter","month"],
           columnList=['Region'],axis=1)
# Out:
# <style  type="text/css" >
#     #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col0 {
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col1 {
#             background-color:  #2121ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col2 {
#             background-color:  #acacff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col4 {
#             background-color:  #1414ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row0_col6 {
#             background-color:  #2929ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col0 {
#             background-color:  #a0a0ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col3 {
#             background-color:  #2828ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col4 {
#             background-color:  #4747ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col5 {
#             background-color:  #3030ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row1_col6 {
#             background-color:  #2323ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col0 {
#             background-color:  #3e3eff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col1 {
#             background-color:  #4848ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col3 {
#             background-color:  #2727ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col5 {
#             background-color:  #8585ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row2_col6 {
#             background-color:  #1313ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col0 {
#             background-color:  #6b6bff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col1 {
#             background-color:  #5252ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col2 {
#             background-color:  #8a8aff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col3 {
#             background-color:  #4444ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row3_col6 {
#             background-color:  #8484ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col0 {
#             background-color:  #2828ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col1 {
#             background-color:  #2e2eff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col3 {
#             background-color:  #3a3aff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col4 {
#             background-color:  #3737ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col5 {
#             background-color:  #ababff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row4_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col0 {
#             background-color:  #2424ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col2 {
#             background-color:  #bdbdff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col3 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col4 {
#             background-color:  #4e4eff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row5_col6 {
#             background-color:  #7575ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col0 {
#             background-color:  #b2b2ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col2 {
#             background-color:  #7e7eff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col3 {
#             background-color:  #c5c5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col4 {
#             background-color:  #bcbcff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row6_col6 {
#             background-color:  #c7c7ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col0 {
#             background-color:  #9f9fff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col1 {
#             background-color:  #3f3fff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col4 {
#             background-color:  #9797ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col5 {
#             background-color:  #6969ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row7_col6 {
#             background-color:  #4343ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row8_col0 {
#             background-color:  #2121ff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row8_col1 {
#             background-color:  #2a2aff;
#             color:  #f1f1f1;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row8_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3ae14058_385f_11eb_8edd_ad9a298ea912row8_col3 {
#             background-color:  #3c3cff;
#             color:  #f1f1f1;

# %%
getHeatMap(df,indexList=["year"], columnList=['month'],axis=1)
# Out:
# C:\Users\immanuel\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col1 {
#             background-color:  #b0b0ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col2 {
#             background-color:  #8686ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col3 {
#             background-color:  #9191ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col4 {
#             background-color:  #9a9aff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col5 {
#             background-color:  #0d0dff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col6 {
#             background-color:  #2121ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col8 {
#             background-color:  #8888ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col9 {
#             background-color:  #9c9cff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col10 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row0_col11 {
#             background-color:  #a3a3ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col0 {
#             background-color:  #c8c8ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col1 {
#             background-color:  #7f7fff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col2 {
#             background-color:  #6161ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col3 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col6 {
#             background-color:  #0e0eff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col7 {
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col8 {
#             background-color:  #cdcdff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col9 {
#             background-color:  #babaff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col10 {
#             background-color:  #9494ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row1_col11 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col0 {
#             background-color:  #8282ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col1 {
#             background-color:  #bebeff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col2 {
#             background-color:  #9393ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col4 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col5 {
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col6 {
#             background-color:  #1010ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col8 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col9 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col10 {
#             background-color:  #7878ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row2_col11 {
#             background-color:  #b1b1ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col0 {
#             background-color:  #8b8bff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col1 {
#             background-color:  #7d7dff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col2 {
#             background-color:  #9090ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col3 {
#             background-color:  #9e9eff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col4 {
#             background-color:  #8383ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col6 {
#             background-color:  #4444ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col7 {
#             background-color:  #3131ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col8 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col9 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col10 {
#             background-color:  #9292ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row3_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col1 {
#             background-color:  #c0c0ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col2 {
#             background-color:  #9090ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col3 {
#             background-color:  #c0c0ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col6 {
#             background-color:  #2020ff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col7 {
#             background-color:  #0c0cff;
#             color:  #f1f1f1;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col8 {
#             background-color:  #dadaff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col9 {
#             background-color:  #b4b4ff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col10 {
#             background-color:  #ceceff;
#             color:  #000000;
#         }    #T_3c7677c6_385f_11eb_9a53_ad9a298ea912row4_col11 {
#             background-color:  #8e8eff;
#             color:  #0

# %%
getHeatMap(df,indexList=["City, State"], columnList=["year"],axis=0)
# Out:
# <style  type="text/css" >
#     #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col0 {
#             background-color:  #4040ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col1 {
#             background-color:  #3d3dff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col2 {
#             background-color:  #4a4aff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col3 {
#             background-color:  #3737ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col4 {
#             background-color:  #6c6cff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col5 {
#             background-color:  #5454ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col6 {
#             background-color:  #2a2aff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col7 {
#             background-color:  #3131ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col8 {
#             background-color:  #3e3eff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row0_col9 {
#             background-color:  #6464ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col0 {
#             background-color:  #2525ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col2 {
#             background-color:  #5151ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col3 {
#             background-color:  #3737ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col4 {
#             background-color:  #4e4eff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col5 {
#             background-color:  #1f1fff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col6 {
#             background-color:  #5252ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col7 {
#             background-color:  #1616ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col8 {
#             background-color:  #3131ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row1_col9 {
#             background-color:  #5151ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col0 {
#             background-color:  #3535ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col1 {
#             background-color:  #3535ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col2 {
#             background-color:  #2b2bff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col3 {
#             background-color:  #1f1fff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col4 {
#             background-color:  #5555ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col5 {
#             background-color:  #5a5aff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col6 {
#             background-color:  #6d6dff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col7 {
#             background-color:  #4f4fff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col8 {
#             background-color:  #4848ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row2_col9 {
#             background-color:  #8181ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col0 {
#             background-color:  #6c6cff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col1 {
#             background-color:  #6f6fff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col2 {
#             background-color:  #5050ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col4 {
#             background-color:  #5858ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col5 {
#             background-color:  #4d4dff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col6 {
#             background-color:  #9a9aff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col7 {
#             background-color:  #4949ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col8 {
#             background-color:  #8585ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row3_col9 {
#             background-color:  #5656ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col0 {
#             background-color:  #4b4bff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col1 {
#             background-color:  #7a7aff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col2 {
#             background-color:  #4f4fff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col3 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col4 {
#             background-color:  #2e2eff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col5 {
#             background-color:  #5252ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col6 {
#             background-color:  #5252ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col7 {
#             background-color:  #0c0cff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col8 {
#             background-color:  #4c4cff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row4_col9 {
#             background-color:  #6f6fff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col0 {
#             background-color:  #5b5bff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col1 {
#             background-color:  #6464ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col2 {
#             background-color:  #3434ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col3 {
#             background-color:  #3737ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col4 {
#             background-color:  #5050ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col5 {
#             background-color:  #5050ff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col6 {
#             background-color:  #7171ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col7 {
#             background-color:  #4b4bff;
#             color:  #f1f1f1;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col8 {
#             background-color:  #6666ff;
#             color:  #000000;
#         }    #T_81a16a0a_385f_11eb_a8c9_ad9a298ea912row5_col9 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;

# %%
df.groupby(["year","quarter","Profit/Loss"])["Profit/Loss"].count().unstack()
# Out:
# Profit/Loss   Loss  Profit
# year quarter
# 2011 Q 1       319     360
#      Q 2       289     367
#      Q 3       290     379
#      Q 4       331     387
# 2012 Q 1       322     391
#      Q 2       328     339
#      Q 3       316     407
#      Q 4       334     366
# 2013 Q 1       300     374
#      Q 2       301     345
#      Q 3       265     415
#      Q 4       318     399
# 2014 Q 1       293     377
#      Q 2       279     393
#      Q 3       281     391
#      Q 4       314     348
# 2015 Q 1       305     375
#      Q 2       301     384
#      Q 3       286     413
#      Q 4       284     404
# 2016 Q 1       303     387
#      Q 2       298     373
#      Q 3       271     404
#      Q 4       305     361
# 2017 Q 1       294     362
#      Q 2       313     387
#      Q 3       310     390
#      Q 4       319     404
# 2018 Q 1       303     349
#      Q 2       304     408
#      Q 3       254     381
#      Q 4       316     394
# 2019 Q 1       289     370
#      Q 2       270     344
#      Q 3       278     402
#      Q 4       327     399
# 2020 Q 1       312     402
#      Q 2       283     351
#      Q 3       284     391
#      Q 4       195     236

# %%
import calendar
def getSummary(subtype):
    d1={}
    for year in df["year"].unique():
        for region in df["Region"].unique():
            DF=df[(df["year"]==year) & (df["Region"]==region)]
            if subtype=="A":
                DF=DF.groupby(["quarter","Profit/Loss"])["Profit/Loss"].count().unstack()
                DF=DF[["Profit","Loss"]]
            elif subtype=="B":
                DF=pd.pivot_table(DF, values = 'ROI', index=["quarter"], columns = 'Region')
            elif subtype=="C":
                DF=pd.pivot_table(DF, values = 'ROI', index=["month"], columns = 'Region')
                DF.index=DF.index.map(lambda x:calendar.month_abbr[x])
            DF=DF.round(3)
            d1[f"{year}-{region}"]={"df":DF}
    return d1

# %%
getSummary("A")['2011-NORTHEAST']["df"]
# Out:
# Profit/Loss  Profit  Loss
# quarter
# Q 1             100    83
# Q 2              80    63
# Q 3              91    68
# Q 4             100    72

# %%
getSummary("B")['2011-NORTHEAST']["df"]
# Out:
# Region   NORTHEAST
# quarter
# Q 1          0.086
# Q 2          0.133
# Q 3          0.135
# Q 4          0.095

# %%
getSummary("C")['2011-NORTHEAST']["df"]
# Out:
# Region  NORTHEAST
# month
# Jan         0.054
# Feb         0.144
# Mar         0.068
# Apr         0.091
# May         0.100
# Jun         0.208
# Jul         0.109
# Aug         0.188
# Sep         0.099
# Oct         0.057
# Nov         0.116
# Dec         0.106

# %%
Q=d1['2011-NORTHEAST']["df"]
Q.index
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object', name='month')

# %%
def InsertTable(_DICTIONARY,_WRITER,title):
    row=0
    for i,x in enumerate(_DICTIONARY):
        tempDF=_DICTIONARY[x]["df"]
        sLen=len(tempDF[tempDF.columns[0]])
        tempDF.to_excel(_WRITER,
                        sheet_name = title
                        ,startrow=row, startcol=0)
        row=(row+sLen+2)

# %%
def InsertChart(_DICTIONARY,
                _WORKSHEET,
                WORKBOOK,
                _SheetName):
    chart_List=[]
    _Row=1
    _Columns=0
    for i,x in enumerate(_DICTIONARY):
        title=f"{x}"
        tempDF=_DICTIONARY[x]["df"]
        qaz=tempDF.iloc[0]
        sLen=len(qaz)+1
        rLen=len(list(_DICTIONARY[x]["df"].index))
        chart = WORKBOOK.add_chart({'type': 'column'})
        for col_num in range(1, sLen):
            chart.add_series({
                'name':       [_SheetName, _Columns, col_num],
                'categories': [_SheetName, _Row, 0, (rLen+_Row-1), 0],
                'values':     [_SheetName, _Row, col_num, (rLen+_Row-1), col_num],
                'overlap':    -5,
                'data_labels': {'value': True,
                                'font': {'name': 'Calibri', "bold":True, "size":10}}
            })
            chart.set_x_axis({'name':"", 'major_gridlines': {'visible': False}})
            chart.set_y_axis({'name':"", 'major_gridlines': {'visible': False}})
        chart.set_title ({'name':title})
        chart.set_legend({'position': 'none'})
        chart.set_size({'width': 700, 'height': 477.252})
        chart_List.append(chart)
        _Row =_Row+rLen+2
        _Columns = _Columns+rLen+2
    # ------------------------------------------------------------------------------------
    # Insert the chart into the worksheet.
    num1=1
    num2=5
    _count_=0
    cellDict={1: 'A', 2: 'L', 3: 'W', 4: 'AH', 5: 'AS', 6: 'BD', 7: 'BO'}
    for i,x in enumerate(_DICTIONARY):
        _count_+=1
        _WORKSHEET.insert_chart(cellDict[_count_]+str(num1), chart_List[i],{"x_scale":1,"y_scale":1})
        if _count_ == 7:
            _count_= 0
            num1+=24

# %%
def SaveChartsToFile(dictList,savePath):
    CurrentDate=datetime.datetime.now().date()
    with pd.ExcelWriter(f"{savePath}\ROI [{CurrentDate}].xlsx") as writer:
        workbook  = writer.book
        Dashboard_1 = workbook.add_worksheet("Graphs 1")
        Dashboard_2 = workbook.add_worksheet("Graphs 2")
        Dashboard_3 = workbook.add_worksheet("Graphs 3")
        DashboardList=[Dashboard_1,Dashboard_2,Dashboard_3]
        for x in DashboardList:
            x.set_zoom(36)
        RefList=["Ref 1","Ref 2","Ref 3"]
        for a,b,c in zip(dictList,DashboardList,RefList):
            InsertTable(a,writer,c)
            InsertChart(a,b,workbook,c)

# %%
savePath=r"C:\Users\immanuel\Desktop\FEED MIGRATION\Data Migration\Sales Data\Summary"
dictList=[getSummary("A"),getSummary("B"),getSummary("C")]
SaveChartsToFile(dictList,savePath)

# %%
# save each yeat to a json file
import json
for x in df["year"].unique():
    jObject=df[df["year"]==x]
    jObject["Date"]=jObject["Date"].astype(str)
    jObject=jObject.to_json(orient="records")
#     jObject=jObject.to_json(orient="table")
    with open(f"{x} Data.json", 'w') as f:
        f.write(jObject)
        
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
# Out:
# C:\Users\immanuel\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
